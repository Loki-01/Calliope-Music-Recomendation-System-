# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
import plotly.offline as pyo
from wordcloud import WordCloud, STOPWORDS

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv('data.csv')

# %%
genre_data = pd.read_csv('data_by_genres.csv')

# %%
year_data = pd.read_csv('data_by_year.csv')

# %%
artist_data = pd.read_csv('data_by_artist.csv')

# %%
print("First 2 rows of data")
print(data.head(2))
# Out:
# First 2 rows of data
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz             0.878
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8             0.000
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
#
#    speechiness   tempo
# 0       0.0366  80.954
# 1       0.4150  60.936

# %%
print("First 2 rows of genre_data")
print(genre_data.head(2))
# Out:
# First 2 rows of genre_data
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834    0.3616 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762    0.1310 -16.854000     0.076817  120.285667
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# 1  0.221750   52.500000    5

# %%
print("First 2 rows of year_data")
print(year_data.head(2))
# Out:
# First 2 rows of year_data
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878   0.20571 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195   0.24072 -19.275282     0.116655  100.884521  0.535549
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10

# %%
print("First 2 rows of artist_data")
print(artist_data.head(2))
# Out:
# First 2 rows of artist_data
#    mode  count  acousticness                           artists  danceability  \
# 0     1      9      0.590111  "Cats" 1981 Original London Cast      0.467222
# 1     1     26      0.862538         "Cats" 1983 Broadway Cast      0.441731
#
#      duration_ms    energy  instrumentalness  liveness  loudness  speechiness  \
# 0  250318.555556  0.394003          0.011400  0.290833   -14.448     0.210389
# 1  287280.000000  0.406808          0.081158  0.315215   -10.690     0.176212
#
#         tempo   valence  popularity  key
# 0  117.518111  0.389500   38.333333    5
# 1  103.044154  0.268865   30.576923    5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
#  16  release_date      170653 non-null  object
#  17  speechiness       170653 non-null  float64
#  18  tempo             170653 non-null  float64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 24.7+ MB

# %%
genre_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2973 entries, 0 to 2972
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              2973 non-null   int64
#  1   genres            2973 non-null   object
#  2   acousticness      2973 non-null   float64
#  3   danceability      2973 non-null   float64
#  4   duration_ms       2973 non-null   float64
#  5   energy            2973 non-null   float64
#  6   instrumentalness  2973 non-null   float64
#  7   liveness          2973 non-null   float64
#  8   loudness          2973 non-null   float64
#  9   speechiness       2973 non-null   float64
#  10  tempo             2973 non-null   float64
#  11  valence           2973 non-null   float64
#  12  popularity        2973 non-null   float64
#  13  key               2973 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 325.3+ KB

# %%
data["decade"] = data["year"].apply(lambda x: f"{(x // 10) * 10}s")

# %%
print(data[["year", "decade"]].head(5))
# Out:
#    year decade
# 0  1921  1920s
# 1  1921  1920s
# 2  1921  1920s
# 3  1921  1920s
# 4  1921  1920s

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="decade", data=data, order=sorted(data["decade"].unique()))
plt.title("Number of Tracks per Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Tracks")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sound_features = [
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "liveness",
    "valence"
]

fig = px.line(
    year_data,
    x="year",
    y=sound_features,
    title="Trend of various sound features over decades"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fe74d356-f99d-45e8-8c7a-1f9a8cad5567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe74d356-f99d-45e8-8c7a-1f9a8cad5567")) {                    Plotly.newPlot(                        "fe74d356-f99d-45e8-8c7a-1f9a8cad5567",                        [{"hovertemplate":"variable=acousticness\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"acousticness","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"acousticness","orientation":"v","showlegend":true,"x":[1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[0.8868960000000005,0.9385915492957748,0.9572467913513516,0.940199860169493,0.9626070503597138,0.660817216981134,0.9361794552845558,0.9386165035685952,0.6014265861344558,0.936714937370057,0.8330399585921336,0.9357705179282878,0.899897909117222,0.8911487501730107,0.7783855599472987,0.7723120800000008,0.8654357853881286,0.9192803908646014,0.9087381000000004,0.8476440499999951,0.8957376562500025,0.8529343703923857,0.9027523185915528,0.9076531914893636,0.7096568630000005,0.9199445823665852,0.9139650224242392,0.9221549999999956,0.9075328949999956,0.8539413005999965,0.9022971956499974,0.8743009244999965,0.8909223502564074,0.8650197272999992,0.8405510069999986,0.8230569899999975,0.7928023589743608,0.7796118650000005,0.7793927897435907,0.7671814843243259,0.7519038684210535,0.720607806842106,0.7227048300000004,0.6941005307692291,0.6099113295384619,0.5248094599699997,0.5296103243521767,0.4937702403500001,0.4488463039999994,0.4600571139500007,0.4583362981000009,0.4600428051999994,0.4165241889999992,0.4472074226000001,0.4337738871950005,0.3614706321099993,0.3393025333750004,0.3289685734499993,0.29593224063,0.284955397635897,0.3012042267400006,0.2895800382050001,0.2947778916300001,0.2877095803450008,0.2965709032099995,0.2850806564249999,0.3116640663948722,0.322009946512821,0.3133512518150009,0.3328699505850001,0.3327652916307699,0.3208087638250009,0.3090685537400004,0.3062343630899999,0.3025118061200004,0.3010268798000006,0.3067156934549995,0.2914894615700001,0.2715901110661201,0.2893227005163599,0.2868424748428934,0.282624289885001,0.2564705181729783,0.2805589466225845,0.2557635068666665,0.2799863520256408,0.2540809575538463,0.2491917627212275,0.261928619096939,0.2426866435515872,0.2731826625185919,0.2499530443804624,0.2574880859564779,0.249312645880299,0.2539522577102332,0.2841710299554814,0.2860990665261043,0.2676329907750836,0.2782985863365824,0.2199308880935964],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=danceability\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"danceability","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"danceability","orientation":"v","showlegend":true,"x":[1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998, ...

# %%
top10_genres = genre_data.sort_values("popularity", ascending=False).head(10)

fig = px.bar(
    top10_genres,
    x="genres",
    y=["valence", "energy", "danceability", "acousticness"],
    barmode="group",
    title="Trend of various sound features over top 10 genres"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bd8e9dfa-5a12-42b5-882e-8c797bf5ff1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd8e9dfa-5a12-42b5-882e-8c797bf5ff1a")) {                    Plotly.newPlot(                        "bd8e9dfa-5a12-42b5-882e-8c797bf5ff1a",                        [{"alignmentgroup":"True","hovertemplate":"variable=valence\u003cbr\u003egenres=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"valence","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"valence","offsetgroup":"valence","orientation":"v","showlegend":true,"textposition":"auto","x":["basshall","trap venezolano","south african house","turkish edm","alberta hip hop","chinese electropop","afroswing","indie triste","guaracha","russian dance"],"xaxis":"x","y":[0.5886666666666667,0.706,0.8343333333333334,0.364,0.937,0.199,0.676625,0.189,0.556,0.326],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=energy\u003cbr\u003egenres=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"energy","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"energy","offsetgroup":"energy","orientation":"v","showlegend":true,"textposition":"auto","x":["basshall","trap venezolano","south african house","turkish edm","alberta hip hop","chinese electropop","afroswing","indie triste","guaracha","russian dance"],"xaxis":"x","y":[0.6301666666666668,0.777,0.5623333333333332,0.7190000000000001,0.685,0.787,0.5801875,0.159,0.972,0.945],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=danceability\u003cbr\u003egenres=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"danceability","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"danceability","offsetgroup":"danceability","orientation":"v","showlegend":true,"textposition":"auto","x":["basshall","trap venezolano","south african house","turkish edm","alberta hip hop","chinese electropop","afroswing","indie triste","guaracha","russian dance"],"xaxis":"x","y":[0.8180000000000001,0.877,0.847,0.698,0.885,0.66,0.71175,0.83,0.745,0.653],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=acousticness\u003cbr\u003egenres=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"acousticness","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"acousticness","offsetgroup":"acousticness","orientation":"v","showlegend":true,"textposition":"auto","x":["basshall","trap venezolano","south african house","turkish edm","alberta hip hop","chinese electropop","afroswing","indie triste","guaracha","russian dance"],"xaxis":"x","y":[0.2131666666666666,0.0446,0.0438333333333333,0.00829,0.33,0.00257,0.31845,0.946,0.00903,0.00561],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"hea ...

# %%
comment_words = " ".join(genre_data["genres"].tolist())

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(
    width=800,
    height=800,
    background_color="white",
    stopwords=stopwords,
    max_words=40,
    min_font_size=10
).generate(comment_words)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud of Music Genres")
plt.tight_layout()
plt.show()

# %%
comment_words = " ".join(artist_data["artists"].tolist())

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(
    width=800,
    height=800,
    background_color="white",
    stopwords=stopwords,
    min_word_length=3,
    max_words=40,
    min_font_size=10
).generate(comment_words)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud of Artists")
plt.tight_layout()
plt.show()

# %%
top10_most_song_produced_artists = artist_data.sort_values(
    "count", ascending=False
).head(10)

print("===Top 10 Artists by Number of Songs===")
print(
    top10_most_song_produced_artists[["count", "artists"]].sort_values(
        "count", ascending=False
    ).to_string(index=False)
)
# Out:
# ===Top 10 Artists by Number of Songs===
#  count           artists
#   3169  Francisco Canaro
#   2422  Эрнест Хемингуэй
#   2136 Эрих Мария Ремарк
#   1459     Frank Sinatra
#   1256   Ignacio Corsini
#   1200 Vladimir Horowitz
#   1146  Arturo Toscanini
#   1103    Billie Holiday
#   1061       Johnny Cash
#   1023     Elvis Presley

# %%
top10_popular_artists = artist_data.sort_values(
    "popularity", ascending=False
).head(10)

print("\n=== Top 10 Artists by Popularity Score ===")
print(
    top10_popular_artists[["popularity", "artists"]].sort_values(
        "popularity", ascending=False
    ).to_string(index=False)
)
# Out:
# === Top 10 Artists by Popularity Score ===
#  popularity         artists
#        93.0     Ritt Momney
#        92.0       Lele Pons
#        90.0 Los Legendarios
#        89.0        Jerry Di
#        88.0          Emilee
#        88.0     salem ilese
#        88.0       Surf Mesa
#        87.0             A7S
#        86.0    Lenny Santos
#        86.0       Master KG

# %% [markdown]
# **Conclusion About Data**
#
# 1/ Most songs in the dataset were released after the 1990s. This matches the growth of digital music and streaming platforms.
#
# 2/ Acousticness dropped sharply after the 1950s as electric instruments replaced acoustic ones. Energy and danceability both increased over time.
#
# 3/ Loudness has gone up every decade. Music producers make songs louder to stand out, a trend known as the loudness war.
#
# 4/ The top 10 genres have high energy and danceability, which shows that popular music tends to be upbeat.
#
# 5/ The genre word cloud is dominated by pop, rock, and hip-hop. The artist word cloud is led by classic artists with large catalogs.
#
# 6/ The most popular artists by score are recent artists, because popularity is based on recent streaming activity, not the size of the catalog.

# %%
print("data shape:", data.shape)
print("genre_data shape:", genre_data.shape)
# Out:
# data shape: (170653, 20)
# genre_data shape: (2973, 14)

# %%
feature_cols = [
    "acousticness",
    "danceability",
    "energy",
    "instrumentalness",
    "liveness",
    "loudness",
    "speechiness",
    "tempo",
    "valence",
    "popularity"
]

# %%
genre_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("kmeans", KMeans(n_clusters=12, n_init=10, random_state=42))
])

genre_pipeline.fit(genre_data[feature_cols])

genre_data["cluster"] = genre_pipeline["kmeans"].labels_

print("=== Genre Cluster Sizes ===")
print(genre_data["cluster"].value_counts().sort_index())
# Out:
# === Genre Cluster Sizes ===
# cluster
# 0     230
# 1     324
# 2     282
# 3      21
# 4     224
# 5     427
# 6     100
# 7     375
# 8     193
# 9      60
# 10    204
# 11    533
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
genre_scaled = scaler.fit_transform(genre_data[feature_cols])

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=20)
tsne_result = tsne.fit_transform(genre_scaled)

# %%
genre_data["tsne_x"] = tsne_result[:, 0]
genre_data["tsne_y"] = tsne_result[:, 1]

# %%
genre_data["cluster"] = genre_data["cluster"].astype(str)

# %%
fig = px.scatter(
    genre_data,
    x="tsne_x",
    y="tsne_y",
    color="cluster",
    hover_data=["genres"],
    title="Genre Clusters visualized with t-SNE"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7b981d03-3bba-433f-8146-fac08df47eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b981d03-3bba-433f-8146-fac08df47eab")) {                    Plotly.newPlot(                        "7b981d03-3bba-433f-8146-fac08df47eab",                        [{"customdata":[["21st century classical"],["432hz"],["african-american classical"],["ambient"],["ambient pop"],["american 21st century classical"],["american classical piano"],["american contemporary classical"],["american early music"],["armenian folk"],["asmr"],["atmosphere"],["australian ambient"],["australian classical piano"],["austrian classical piano"],["avant-garde"],["background music"],["background piano"],["balkan classical piano"],["baltic classical"],["bansuri"],["baroque brass"],["baroque singing"],["belgian classical piano"],["berlin school"],["bible"],["binaural"],["boy soprano"],["brain waves"],["brass quintet"],["brazilian classical piano"],["brazilian contemporary classical"],["breton folk"],["british choir"],["british classical piano"],["british contemporary classical"],["british orchestra"],["british soundtrack"],["bulgarian experimental"],["calming instrumental"],["cambridge choir"],["canadian classical piano"],["canadian post-rock"],["canadian soundtrack"],["cathedral choir"],["caucasian classical piano"],["chakra"],["chamber choir"],["chamber ensemble"],["chamber orchestra"],["chill guitar"],["chinese classical performance"],["chinese classical piano"],["choral"],["christmas instrumental"],["classical cello"],["classical clarinet"],["classical countertenor"],["classical flute"],["classical guitar"],["classical harp"],["classical horn"],["classical oboe"],["classical organ"],["classical performance"],["classical piano"],["classical piano duo"],["classical piano trio"],["compositional ambient"],["contemporary choir"],["contemporary classical"],["contemporary classical piano"],["contrabass"],["danish electropop"],["dark jazz"],["deep soundtrack"],["dinner jazz"],["drift"],["drone"],["duduk"],["dutch classical piano"],["early music choir"],["ecm-style jazz"],["ethiopian pop"],["experimental ambient"],["experimental guitar"],["fingerstyle"],["finnish contemporary classical"],["focus"],["fourth world"],["french classical piano"],["german classical piano"],["german jazz"],["german renaissance"],["german soundtrack"],["guitarra clasica"],["guzheng"],["hangpan"],["harp"],["hauntology"],["healing"],["historical keyboard"],["hungarian choir"],["hungarian classical performance"],["hungarian classical piano"],["hungarian contemporary classical"],["icelandic classical"],["icelandic experimental"],["indian fusion"],["irish indie"],["israeli classical piano"],["italian baroque ensemble"],["italian classical guitar"],["italian classical piano"],["italian jazz"],["j-ambient"],["japanese classical"],["japanese classical performance"],["japanese classical piano"],["japanese concert band"],["japanese electronic"],["japanese idm"],["kirtan"],["korean classical performance"],["korean classical piano"],["latin american classical piano"],["lullaby"],["medieval"],["meditation"],["microtonal"],["middle earth"],["minimalism"],["mizrahi"],["modern jazz piano"],["modern jazz trio"],["modern performance"],["modern string quartet"],["musica de fondo"],["native american flute"],["native american spiritual"],["neo-classical"],["new age"],["new age piano"],["new isolationism"],["new zealand classical"],["nordic classical piano"],["nordic orchestra"],["nordic soundtrack"],["norwegian choir"],["norwegian classical"],["norwegian experimental"],["norwegian jazz"],["nu age"],["oceania soundtrack"],["orthodox chant"],["oxford choir"],["panpipe"],["piano cover"],["polish classical piano"],[" ...

# %%
song_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("kmeans", KMeans(n_clusters=25, n_init=10, random_state=42))
])

song_pipeline.fit(data[feature_cols])
data["cluster"] = song_pipeline["kmeans"].labels_

print("=== Song Cluster Sizes ===")
print(data["cluster"].value_counts().sort_index())
# Out:
# === Song Cluster Sizes ===
# cluster
# 0      7807
# 1      5036
# 2      9778
# 3      4702
# 4      5519
# 5      5169
# 6      4615
# 7      7987
# 8      4193
# 9      8106
# 10     8200
# 11     8616
# 12     7253
# 13     3412
# 14     8449
# 15     6679
# 16     8552
# 17    11555
# 18     7648
# 19     4225
# 20     7559
# 21     7457
# 22     7313
# 23     5311
# 24     5512
# Name: count, dtype: int64

# %%
song_scaled = scaler.fit_transform(data[feature_cols])

pca = PCA(n_components=2)
pca_result = pca.fit_transform(song_scaled)

var_kept = sum(pca.explained_variance_ratio_) * 100
print(f"Information kept after PCA: {var_kept:.1f}%")

data["pca_x"] = pca_result[:, 0]
data["pca_y"] = pca_result[:, 1]
data["cluster"] = data["cluster"].astype(str)

sample = data.sample(n=10000, random_state=42)

fig = px.scatter(
    sample,
    x="pca_x",
    y="pca_y",
    color="cluster",
    hover_data=["name", "artists"],   # hover → song name + artist
    title="Song Clusters visualized with PCA"
)
fig.show()
# Out:
# Information kept after PCA: 49.0%
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c75f3671-fef1-4706-b071-f6e94b235eab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c75f3671-fef1-4706-b071-f6e94b235eab")) {                    Plotly.newPlot(                        "c75f3671-fef1-4706-b071-f6e94b235eab",                        [{"customdata":[["Camby Bolongo","['Idris Muhammad']"],["Sh Boom (Life Could Be A Dream)","['Kenny Vance and the Planotones']"],["Cha cha cha de las segretarias - Remastered","['Michelino e il suo complesso']"],["Man Of Steel","['Hank Williams, Jr.']"],["Al Final De Nuestra Historia","['La Arrolladora Banda El Limón De Rene Camacho']"],["Tenías Que Ser Tan Cruel","['Rocío Dúrcal']"],["Song to See You Through","['The Doobie Brothers']"],["Por Que Te Conocí","['Los Temerarios']"],["Back Door Man","['Willie Dixon']"],["Monday Morning","['Fleetwood Mac']"],["Siempre Te Voy A Querer","['Industria del Amor']"],["Completamente Enamorados","['Eros Ramazzotti']"],["For What It's Worth","['Buffalo Springfield']"],["Rip It Up","['Bill Haley & His Comets']"],["That's The Way It Goes - Remastered 2004","['George Harrison']"],["It Ain't Necessarily So","['Bronski Beat']"],["Spanish Girl","['Julio Iglesias']"],["The Lovely Linda - Remastered 2011","['Paul McCartney']"],["Straight On","['Heart']"],["Easy to Love You - 2013 Remaster","['Grateful Dead']"],["Real Love","['Skyy']"],["These Days (feat. 77 Jefferson)","['Josh Heinrichs']"],["May I Have This Dance (Remix) [feat. Chance the Rapper]","['Francis and the Lights', 'Chance the Rapper']"],["Weak in the Presence of Beauty","['Alison Moyet']"],["Give It to Me","['The J. Geils Band']"],["Took the Last Train","['David Gates']"],["Rip Her To Shreads","['Blondie']"],["Pinky Ring","['UGK']"],["Sorrow - 2015 Remaster","['David Bowie']"],["So Nice (Summer Samba)","['Marcos Valle']"],["The Closer You Get","['Alabama']"],["Texas (When I Die)","['Tanya Tucker']"],["Am I Blue","['George Strait']"],["HF V CMV.Iii","['Future Rapper']"],["Smackwater Jack","['Carole King']"],["Out Of Time","['The Rolling Stones']"],["Jukebox in My Mind","['Alabama']"],["Que Chulada De Mujer","['Ezequiel Peña']"],["Muñecas Del Cha Cha Chá","['La Sonora Matancera', 'Celia Cruz']"],["Thugz Mansion - 2Pac Original\u002fAcoustic","['2Pac']"],["Stay up Late","['Talking Heads']"],["Down Home Blues","['Z.Z. Hill']"],["Taxi Cab","['Vampire Weekend']"],["Vamos fugir","['Gilberto Gil']"],["Too Close","['Next']"],["Lost Again","['kalapana']"],["Little Drummer Boy","['Mannheim Steamroller']"],["El Espinazo Del Diablo","['Los Tigres Del Norte']"],["Tom's Diner","['Suzanne Vega', 'DNA']"],["One Evening","['Feist']"],["Love...Can Be So Wonderful","['The Temprees']"],["Everybody Dance - 2018 Remaster","['CHIC']"],["This Is Your World","['Sam & Dave']"],["I Want Candy","['Bow Wow Wow']"],["Who Will Save Your Soul","['Jewel']"],["(Lay Your Head On My) Pillow","['Tony! Toni! Toné!']"],["Crazy Little Thing Called Love","['Queen']"],["El Camaroncito","['Augustin Ramirez']"],["Kill You","['Korn']"],["The Gremlin Rag - Full Version","['Jerry Goldsmith']"],["Down in Hollywood","['Ry Cooder']"],["Jingle Bell Rock","['Bobby Helms']"],["Welcome to the Room... Sara - 2017 Remaster","['Fleetwood Mac']"],["Six Blade Knife","['Dire Straits']"],["Paso del norte","['Los Broncos de Reynosa']"],["Sweet Honey Bee","['Lee Morgan']"],["I'm In Love","['Evelyn \"Champagne\" King']"],["Certainly - Flipped It","['Erykah Badu']"],["Nueve y Quince - 9: 15","['Aventura']"],["Are You Ready for the Country? - 2009 Remaster","['Neil Young']"],["Te Vengo A Buscar","['Los Baron De Apodaca']"],["Just the Two of Us (feat. Bill Withers)","['Grover Washington, Jr.', 'Bill Withers']"],["Must of Got Lost","['The J. Geils Band' ...

# %%
inertias = []
k_range = range(2, 20)

for k in k_range:
    km = KMeans(n_clusters=k, n_init=10, random_state=42)
    km.fit(genre_scaled)
    inertias.append(km.inertia_)

plt.plot(k_range, inertias, marker='o')
plt.xlabel("Number of clusters K")
plt.ylabel("Inertia (within-cluster sum of squares)")
plt.title("Elbow Method — Optimal K")
plt.show()

# %%
score = silhouette_score(genre_scaled, genre_data["cluster"])
print(f"Silhouette Score: {score:.3f}")
# Out:
# Silhouette Score: 0.143
